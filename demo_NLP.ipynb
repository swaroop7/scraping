# %%
import glob
import pandas as pd
import numpy as np
import os
import time
import re
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
lmtzr = WordNetLemmatizer()
from nltk import word_tokenize
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from tqdm import tqdm
from nltk.stem.porter import *
from sklearn.neighbors import KNeighborsClassifier

stemmer = PorterStemmer()



os.chdir('/Users/krothaps/Desktop/hackathon/demo')

# %%
def inlcude_only_nouns(lines):
    # function to test if something is a noun
    is_noun = lambda pos: pos[:2] == 'NN'

    tokenized = nltk.word_tokenize(lines)
    nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if is_noun(pos)] 

    return ' '.join(nouns)

# %%
def tokenize_file_data2(file_name):

    with open(filename) as f:
        content = f.readlines()
        
    # remove the short words     
    shortword = re.compile(r'\W*\b\w{1,3}\b')
    
    file_text_data = ''
    for line in content:
        line = line.decode('utf-8')
        text_data = "\t".join(line.split("\t", 2)[2:])
        # include only nouns
        text_data = inlcude_only_nouns(text_data)
        # remove words which are 3 characters or less
        text_data = shortword.sub('', text_data)
        # remove urls
        text_data = re.sub(r'http\S+', '', text_data)
        text_data = re.sub(r'https\S+', '', text_data)
        text_data = ''.join([i for i in text_data if not i.isdigit()])
#         lemmatization
        text_data = ' '.join([lmtzr.lemmatize(word) for word in text_data.split()])
#         stemming        
        text_data = ' '.join([stemmer.stem(word) for word in text_data.split()])
        # spell correction
#         text_data = text_data.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ').replace('  ', ' ')
        text_data = text_data.lower()
        #include only numerical data
        text_data = re.sub(r"[^a-z]+", ' ', text_data)
        
        file_text_data += text_data
    print file_text_data  
    f.close()
#     return filename+'\t'+file_text_data

# %%
import time

start_time = time.time()

output = open('school_web_parsed_data.txt', 'w')

count = 0

for filename in glob.glob(os.path.join('*.txt')):
    if 'western' not in filename:
        continue
        
    count += 1
    start1_time = time.time()
    file_data = tokenize_file_data2(filename)
#     output.write(file_data+'\n')
    print file_data
    
# output.close()

print "--- Finished parsing text in " + str(time.time() - start_time)+' seconds---'
# Out:
# http part governor univers degre admiss tuition financi call request info appli busi teacher health nurs bachelor degre busi manag busi healthcar manag busi human resourc manag busi inform technolog manag market manag account health inform manag colleg health profess master degre master busi administr inform technolog manag healthcar manag master health leadership colleg health profess manag leadership account data analyt colleg inform technolog bachelor licensur educ educ mathemat mathemat scienc educ middl grade scienc educ secondari chemistri scienc educ secondari physic scienc educ biolog scienc scienc educ earth scienc master licensur teach elementari educ teach educ secondari teach mathemat educ middl grade teach mathemat educ secondari teach scienc educ secondari post baccalaur elementari educ graduat degre teacher curriculum instruct educ instruct design learn technolog leadership languag learn prek endors prepar educ leadership endors prepar english languag learn prek mathemat educ mathemat educ mathemat educ scienc educ middl grade scienc educ secondari chemistri scienc educ secondari physic scienc educ biolog scienc scienc educ earth scienc bachelor degre cloud system administr comput scienc cybersecur inform assur data management data analyt inform technolog network oper secur softwar develop health inform manag colleg health profess busi inform technolog manag colleg busi master degre cybersecur inform assur data analyt inform technolog manag inform technolog manag colleg busi bachelor degre nurs onlin nurs prelicensur health inform manag busi healthcar manag colleg busi master degre nurs educ nurs leadership manag nurs nurs informat nurs educ option nurs leadership manag option nurs nurs informat option master health leadership healthcar manag colleg busi appli admiss enrol checklist admiss requir teacher colleg admiss requir colleg busi admiss requir colleg admiss requir colleg health profess admiss requir transfer earn transfer credit commun colleg transfer request transcript tuition fee scholarship corpor reimburs financi appli financi consum inform guid your financi oblig militari support tuition assist part tim option million scholarship program scholarship student student alumni educ accredit recognit faculti univers govern review job newsroom blog partnership back school scholarship bachelor master degre appli today back school scholarship degre busi overview bachelor degre busi manag busi healthcar manag busi human resourc manag busi inform technolog manag market manag account health inform manag master degre master busi administr inform technolog manag healthcar manag master health leadership manag leadership account data analyt teacher overview bachelor licensur educ educ mathemat mathemat scienc educ middl grade scienc educ secondari chemistri scienc educ secondari physic scienc educ biolog scienc scienc educ earth scienc master licensur teach elementari educ teach educ secondari teach mathemat educ middl grade teach mathemat educ secondari teach scienc educ secondari post baccalaur elementari educ graduat degre teacher curriculum instruct educ instruct design learn technolog leadership languag learn prek endors prepar educ leadership endors prepar english languag learn prek mathemat educ mathemat educ mathemat educ scienc educ middl grade scienc educ secondari chemistri scienc educ secondari physic scienc educ biolog scienc scienc educ earth scienc overview bachelor degre cloud system administr comput scienc cybersecur inform assur data management data analyt inform technolog network oper secur softwar develop health inform manag busi inform technolog manag master degre cybersecur inform assur data analyt inform technolog manag inform technolog manag health nurs overview bachelor degre nurs onlin nurs prelicensur health inform manag busi healthcar manag master degre nurs educ nurs leadership manag nurs nurs informat nurs educ option nurs leadership manag option nurs nurs informat option master health  ...
# None
# --- Finished parsing text in 8.84167695045 seconds---

# %%
print "Number of words parsed : "+str(count)
# Out:
# Number of words parsed : 1

# %%
# Convert the text data to TF-IDF

# %%
data = pd.read_csv('/Users/krothaps/Desktop/hackathon/dataset/test_final.txt', delimiter='\t', names=['id','text'])

print data.shape

# tfv = TfidfVectorizer(min_df=250, 
#             strip_accents='unicode', analyzer='word',
#             stop_words = 'english')

tfv = CountVectorizer(max_df=0.95, min_df=1,
                                stop_words='english')

#   ngram_range=(1, 3), token_pattern=r'\w{1,}', use_idf=1,smooth_idf=1,sublinear_tf=1,

df = data['text'].fillna('')

tfv.fit(df)
data_tfv =  tfv.transform(df)
# Out:
# (978, 2)

# %%
print data_tfv.shape
# Out:
# (978, 216083)

# %%
print tfv.get_feature_names()[0:1000]
# Out:
# [u'aa', u'aaa', u'aaaa', u'aaaaaaaaaaaaaaaaaaab', u'aaaaaaaaaaaaaaaaaac', u'aaaaaaaaaaaaaaaab', u'aaaaaaaaaaaaaaaac', u'aaaaaaaaaaaaaaac', u'aaaaaaaac', u'aaaaaaab', u'aaaaaaabaaidbaugbwgjcgsqaaeeaqmcbaifbwyibqmmmweaahedbcesmqvbuwetingbmgyukagx', u'aaaaaabaalgaaaaea', u'aaaaaabaasaaaaaea', u'aaaaaabablaaaaaea', u'aaaaah', u'aaaaannnnnddd', u'aaaart', u'aaab', u'aaabbb', u'aaabbqebaqebaqaaaaaaaaadaaecbaugbwgjcgsbaaef', u'aaac', u'aaae', u'aaafashion', u'aaag', u'aaahc', u'aaahep', u'aaai', u'aaalac', u'aaao', u'aaaqkm', u'aaaqqq', u'aaas', u'aaaw', u'aaawdaqaceqmrad', u'aab', u'aabasta', u'aabbe', u'aabd', u'aabe', u'aabei', u'aabh', u'aabi', u'aables', u'aabod', u'aabourqu', u'aabr', u'aabril', u'aabt', u'aabv', u'aac', u'aacbityagdn', u'aacc', u'aacca', u'aacci', u'aace', u'aachen', u'aachkoo', u'aacj', u'aacke', u'aacn', u'aacomas', u'aacp', u'aacpm', u'aacqi', u'aacr', u'aacrao', u'aacs', u'aacsb', u'aacsvsu', u'aacte', u'aacu', u'aacubo', u'aacupr', u'aacute', u'aad', u'aadaadvp', u'aadame', u'aadams', u'aadb', u'aaddhrbh', u'aadebayo', u'aademobedework', u'aadland', u'aadp', u'aadr', u'aads', u'aadsas', u'aadsm', u'aaea', u'aaec', u'aaeo', u'aaeod', u'aaeopp', u'aaep', u'aaeqgabaeaawer', u'aaeqgadaeaawer', u'aaeqgafaeaawer', u'aaeqgajaeaawer', u'aaeqganaeaawer', u'aaeqgaraeaawer', u'aaeqgataeaawer', u'aaeqgazaeaawer', u'aaeqgbaadiawer', u'aaeqgbaaeaawer', u'aaes', u'aaf', u'aafaf', u'aafcpa', u'aafcpas', u'aafcs', u'aafd', u'aafes', u'aafi', u'aafs', u'aag', u'aagc', u'aaghof', u'aags', u'aagsa', u'aah', u'aahe', u'aahhe', u'aahp', u'aahperd', u'aahrpp', u'aaia', u'aaic', u'aaij', u'aaipr', u'aairaqmraf', u'aairaxeapwd', u'aairaxeapwdu', u'aairz', u'aais', u'aaisha', u'aaj', u'aajaakwt', u'aajioy', u'aajisti', u'aajjsv', u'aajs', u'aakash', u'aaker', u'aakiyah', u'aaklpx', u'aakq', u'aakw', u'aakwii', u'aakxtjdhjvhki', u'aakz', u'aakzkr', u'aalan', u'aalana', u'aalatorr', u'aalbin', u'aalderink', u'aalderinkl', u'aalf', u'aalfs', u'aalh', u'aalhe', u'aaliyah', u'aall', u'aalm', u'aalmuflehi', u'aals', u'aalt', u'aalu', u'aalunda', u'aam', u'aama', u'aamae', u'aamc', u'aamericorps', u'aamf', u'aamft', u'aami', u'aamir', u'aamot', u'aamoth', u'aamq', u'aamqmdt', u'aamrc', u'aams', u'aamt', u'aamu', u'aamusports', u'aana', u'aanapisi', u'aanchal', u'aanderson', u'aandf', u'aandreasson', u'aang', u'aani', u'aanj', u'aanl', u'aanlikla', u'aanonsen', u'aanp', u'aaol', u'aaor', u'aaov', u'aapa', u'aapblank', u'aapc', u'aapd', u'aapf', u'aapg', u'aapi', u'aapicu', u'aapkrzghj', u'aapkxjaenqjkc', u'aapl', u'aapm', u'aapmockinterview', u'aapnews', u'aapor', u'aapp', u'aappa', u'aapr', u'aaprbly', u'aaps', u'aaptiv', u'aapvolunteerform', u'aapyyqu', u'aaq', u'aaqj', u'aaqskzjrgabagealgcwaad', u'aaqskzjrgabageasabiaad', u'aaqskzjrgabageblaesaad', u'aar', u'aarathi', u'aarc', u'aarhus', u'aarin', u'aarkf', u'aarm', u'aaron', u'aaronhernandez', u'aaronrobertson', u'aaronson', u'aarooran', u'aarp', u'aarron', u'aarts', u'aartsen', u'aas', u'aasa', u'aasap', u'aasc', u'aascb', u'aascu', u'aasd', u'aase', u'aasen', u'aaserud', u'aasg', u'aashe', u'aashenews', u'aashi', u'aashir', u'aashni', u'aasia', u'aasjalkmksv', u'aasl', u'aasmund', u'aasn', u'aasp', u'aaspace', u'aaspvo', u'aasqk', u'aasser', u'aassw', u'aast', u'aastha', u'aat', u'aatassi', u'aatg', u'aatgf', u'aatqa', u'aatz', u'aauc', u'aauo', u'aaup', u'aaur', u'aaus', u'aaut', u'aauu', u'aauw', u'aav', u'aavila', u'aavmc', u'aavps', u'aavtp', u'aaw', u'aawch', u'aawd', u'aax', u'aaxa', u'aaxj', u'aaxobgidsznehwinamfl', u'aaxp', u'aaxwaan', u'aay', u'aayam', u'aayf', u'aayi', u'aaylah', u'aaylesworth', u'aaylxhg', u'aayphhflbmrxjs', u'aayphrjmbwryjc', u'aayupy', u'aazf', u'aazg', u'aaziegler', u'aazvdh', u'ab', u'aba', u'ababa', u'abac', u'abacigalupi', u'abacrtg', u'abacus', u'abad', u'abadi', u'abadia', u'abadoo', u'abady', u'abagail', u'abai', u'abaid', u'abaj', u'abajian', u'abajo', u'abaker', u'abakker', u'abakua', u'abal', u'abalihi', u'aban', u'abanderadas', u'abanderados' ...

# %%
print data_tfv
# Out:
#   (0, 92)	5
#   (0, 185)	73
#   (0, 186)	1
#   (0, 951)	14
#   (0, 975)	19
#   (0, 1102)	14
#   (0, 1117)	1
#   (0, 1182)	1
#   (0, 1218)	4
#   (0, 1235)	2
#   (0, 1238)	3
#   (0, 1251)	18
#   (0, 1365)	1
#   (0, 1424)	1
#   (0, 1651)	1
#   (0, 1717)	3
#   (0, 1721)	1
#   (0, 1767)	6
#   (0, 2045)	1
#   (0, 2064)	3
#   (0, 2068)	1
#   (0, 2404)	1
#   (0, 2415)	23
#   (0, 2421)	1
#   (0, 2456)	1
#   :	:
#   (977, 206020)	1
#   (977, 206027)	1
#   (977, 206042)	1
#   (977, 206057)	1
#   (977, 206058)	3
#   (977, 206060)	2
#   (977, 206067)	4
#   (977, 206074)	2
#   (977, 206077)	2
#   (977, 206091)	1
#   (977, 206100)	31
#   (977, 206171)	1
#   (977, 206568)	5
#   (977, 210500)	32
#   (977, 210517)	15
#   (977, 211637)	2
#   (977, 211717)	5
#   (977, 211795)	1
#   (977, 211802)	5
#   (977, 211807)	3
#   (977, 212541)	1
#   (977, 213624)	5
#   (977, 214099)	1
#   (977, 214891)	1
#   (977, 215462)	4

# %%
print tfv.get_feature_names()[92]
# Out:
# aaeopp

# %%
result =  pd.DataFrame(data_tfv.toarray())

# result = result.drop(['id'], axis=1)

result.columns = tfv.get_feature_names()
print len(result.columns)
# Out:
# 28837

# %%
# df1 = final[['id','computing']]

# print df1.shape

# df1.to_csv('two_column_output.txt', sep='\t')

# %%
# Distance Matrix 

import pandas as pd
from scipy.spatial import distance_matrix


print type(data)

tfidf_scores = final.drop(['id'], axis=1)

tfidf_scores_list = tfidf_scores.values.tolist()

id_list = final.ix[:,0].tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# /Users/krothaps/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   del sys.path[0]

# %%
print result.shape
print data.shape


final = pd.concat([data, result], axis=1)

print final.shape

final = final.drop(['text'], axis=1)

print final.shape

sl = pd.Series(school_list)

final['school_name'] = sl.values

final.to_csv('sample_final_count_vectorizer.txt', sep='\t')
# Out:
# (979, 28837)
# (979, 2)
# (979, 28839)
# (979, 28837)

# %%
feature = 'analy'

for x in result.columns:
    if feature in x:
        print x
# Out:
# analys
# analyses
# analysis
# analyst
# analysts
# analytic
# analytical
# analytics
# analyze
# analyzer
# analyzes
# analyzing
# psychoanalysis

# %%
# count vectorizer data

feature = 'applied'

# count_vectorizer_final = final

eda = count_vectorizer_final[['school_name', feature]]

print eda.sort_values(by=feature, ascending=False).head(30)
# Out:
#                                        school_name  applied
# 491                     kean college of new jersey     4183
# 537                               le moyne college     1224
# 512                  western new mexico university      629
# 221                      lewis-clark state college      452
# 237               illinois institute of technology      381
# 174                south florida community college      324
# 762                        dakota state university      321
# 798           texas a & m international university      309
# 450                       missouri baptist college      243
# 666             oklahoma state university-okmulgee      242
# 790                texas a & m university-commerce      241
# 858  virginia polytechnic institute and state univ      220
# 464                          washington university      197
# 217              university of hawaii at west oahu      162
# 391                                   hope college      156
# 874                     highline community college      147
# 438          university of mississippi main campus      127
# 17                  university of alaska fairbanks      123
# 738            new england institute of technology      114
# 159                            university of miami      113
# 685                             arcadia university      112
# 236               university of illinois at urbana      109
# 258                              butler university       98
# 750                      francis marion university       97
# 574                             buffalo state suny       88
# 403                           northwood university       80
# 80                       san jose state university       76
# 570                             suny at binghamton       74
# 846                        george mason university       73
# 23           university of arkansas at little rock       72

# %%
df_uid_school_name = pd.read_csv('/Users/krothaps/Desktop/hackathon/presentation/uid_school_name.txt',  names = ['uid', 'school_name'])

# convert to lower case 
df_uid_school_name['school_name']  =  df_uid_school_name['school_name'].str.lower()
# remove duplicates
df_uid_school_name = df_uid_school_name.drop_duplicates()


print df_uid_school_name.shape

# print df_uid_school_name.dtypes

df_uid_school_name['uid'] = df_uid_school_name['uid'].astype(str)

school_list = []


for x in id_list:
    s = x.replace('.txt', '')
    try:
        matching_row = df_uid_school_name.loc[df_uid_school_name['uid'] == s].iloc[0]
        school_list.append(matching_row['school_name'])
    except:
        school_list.append('missing')

df = pd.DataFrame(tfidf_scores_list, columns=tfidf_scores.columns.tolist(), index=school_list)        
        
distance_matrix = pd.DataFrame(distance_matrix(df.values, df.values), index=df.index, columns=df.index)

print distance_matrix.shape
# Out:
# (17287, 2)
# (979, 979)

# %%
distance_matrix.to_csv('/Users/krothaps/Desktop/hackathon/presentation/distance_matrix2.txt', sep='\t')
